# %%
from builtins import Exception
import urllib3
from bs4 import BeautifulSoup
from requests import get
import mysql.connector
import re
from datetime import date
import datetime

# %% [markdown]
# # Class Kompas Scraping

# %% [markdown]
# class dibawah merupakan proses pengambilan data dari website berita Kompas.com yang dimana pemanggilan semua fungsi dibawah tersebut nantinya akan dipanggil pada fungsi [scrapingDataKompas]

# %%
class Kompas:
    #deklarasi variable global
    url = ""
    mydb = ""
    keyword = ""
    urlDetailData = ""
    date = ""
    
    #fungsi dari inisialisasi data saat memanggil class pertama kali
    def __init__(self, urlBerita, pencarian,searchDate):
        self.url = urlBerita
        self.keyword = pencarian
        try:
            if(searchDate == ""):
                self.date = datetime.datetime.now()
            else:
                self.date = datetime.datetime.strptime(searchDate, '%d-%m-%Y')
        except Exception as e:
            print(e)
        self.mydb = mysql.connector.connect(host="localhost",user="root", password="",database="db-berita-mca")
         
    #fungsi menyimpan data ke database
    def simpanDatabase(self,data):
        mycursor = self.mydb.cursor()
        sql = "INSERT INTO tb_berita (media,judul_berita,label,penulis,release_date,url,content) VALUES (%s,%s,%s,%s,%s,%s,%s)"
        mycursor.execute(sql, data)
        self.mydb.commit()
        return
    
    #fungsi buat validasi data duplicate di database
    def validasiDataDatabase(self,dataBerita):
        mycursor = self.mydb.cursor()
        sql = "SELECT * FROM tb_berita WHERE url = %s"
        dataUrl = dataBerita
        url = (dataBerita,)
        mycursor.execute(sql, url)
        myresult = mycursor.fetchall()
        return myresult
            
    def getUrlDetail(self, page):
        self.urlDetailData = []
        for page in range(page):
            try:
                if(self.keyword == ""):
    #                 dateNow = self.today.strftime("%Y-%m-%d")
                    urlGet = ("https://indeks.kompas.com/?site=all&date="+self.date.strftime("%Y-%m-%d")+"&page={}".format(page+1))
                    try:
                        soup = BeautifulSoup(get(urlGet).text, 'lxml')
                        getContent = soup.find('div','latest--indeks mt2 clearfix')
                        contents = getContent.find_all('div','article__list clearfix')
                        for x in contents: 
                            news_url = x.find('a', href=True).get('href')
                            mergeUrl = (news_url+"?page=all")
                            self.urlDetailData.append(mergeUrl)
                    except Exception as e:
                        continue
                else:
#                     dateNow = self.today.strftime("%Y-%m-%d")
                    try:
                        urlGet = ("https://indeks.kompas.com/?site=all&date="+self.date.strftime("%Y-%m-%d")+"&page={}".format(page+1))
                        soup = BeautifulSoup(get(urlGet).text, 'lxml')
                        getContent = soup.find('div','latest--indeks mt2 clearfix')
                        contents = getContent.find_all('div','article__list clearfix')
                        for x in contents: 
                            news_url = x.find('a', href=True).get('href')
                            mergeUrl = (news_url+"?page=all")
                            self.urlDetailData.append(mergeUrl)
                    except Exception as e:
                        continue
            except Exception as e:
                print("format tanggal anda masukan salah")
                break
                
    def scrapingDataKompas(self):
        self.getUrlDetail(3)
        for dataBerita in self.urlDetailData:
            myresult = self.validasiDataDatabase(dataBerita)
            if(len(myresult)==0):
                try:
                    media = "KOMPAS.com"
                    web_data = get(dataBerita)
                    soup = BeautifulSoup(web_data.text, 'html.parser')
                    page = soup.find('div','container clearfix')
                    title = page.find('h1','read__title').text
                    
                    contentLabel = page.find_all('li','breadcrumb__item')
                    for x in contentLabel:
                        label = x.find('a').text
                    getAuthor = page.find('div','read__credit clearfix')
                    author = getAuthor.find('a').text                    
                    date = page.find('div','read__time').text
                    release_date = date.replace("Kompas.com - ","")
                    detail_text_class = page.find('div','read__content')
                    texts = detail_text_class.find_all('p')
                    news_content = ' '.join([text.text for text in texts])
                    data = (media,title,label,author,release_date,dataBerita,news_content)
                    self.simpanDatabase(data)
                except Exception as e:
                    continue 
            else:
                continue

# %%
url = 'https://www.kompas.com'
pencarian = 'vaksin'
tanggal = '15-10-2021'
testing = Kompas(url,pencarian,tanggal)
testing.getUrlDetail(4) 
testing.urlDetailData
# testing.date.strftime("%Y-%m-%d")
# Out:
# ['https://bola.kompas.com/read/2021/10/15/23590028/5-amunisi-baru-persiraja-dari-pon-xx-papua-2021?page=all',
#  'https://bola.kompas.com/read/2021/10/15/23510018/pubg-mobile-hadirkan-kembali-peta-bersalju-vikendi?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/23430048/2022-upaya-penyelenggaraan-f1-tak-bentrok-dengan-piala-dunia-qatar?page=all',
#  'https://regional.kompas.com/read/2021/10/15/233140178/gibran-sebut-pernyataan-fx-rudy-tenangkan-kisruh-banteng-vs-celeng-di-pdi-p?page=all',
#  'https://regional.kompas.com/read/2021/10/15/231917378/diduga-aniaya-seorang-pendeta-anggota-dprd-sumba-tengah-dilaporkan-ke?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/23165148/5000-fasilitas-olahraga-publik-tersedia-saat-olimpiade-paris-2024?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/231000876/5-tanda-tikus-bersarang-di-rumah?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/23013151/manajemen-subway-citos-diberi-teguran-tertulis-karena-timbulkan-kerumunan?page=all',
#  'https://regional.kompas.com/read/2021/10/15/225932078/11-dari-150-siswa-mts-harapan-baru-ciamis-tewas-tenggelam-saat-susur-sungai?page=all',
#  'https://regional.kompas.com/read/2021/10/15/225911778/harapan-keluarga-tkw-asal-sulbar-yang-terancam-hukuman-mati-di-malaysia?page=all',
#  'https://regional.kompas.com/read/2021/10/15/225638178/khofifah-siapkan-bonus-bagi-peraih-medali-pon-xx-papua-besaran-masih?page=all',
#  'https://bola.kompas.com/read/2021/10/15/22552058/usai-pon-xx-papua-2021-persiraja-rekrut-5-pemain-tim-sepak-bola-aceh?page=all',
#  'https://bola.kompas.com/read/2021/10/15/22523088/link-live-streaming-psg-vs-angers-kickoff-0200-wib?page=all',
#  'https://www.kompas.com/global/read/2021/10/15/224843770/anggota-parlemen-inggris-david-amess-tewas-ditusuk-saat-acara?page=all',
#  'https://regional.kompas.com/read/2021/10/15/224838178/polda-banten-tahan-brigadir-np-yang-banting-mahasiswa-hingga-kejang?page=all',
#  'https://regional.kompas.com/read/2021/10/15/224446078/jatim-peringkat-3-di-pon-papua-khofifah-saya-tetap-bangga-atas-kerja-keras?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/224000976/cara-menghilangkan-bau-tak-sedap-pada-kasur-tanpa-perlu-dicuci?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/22330431/wna-yang-jadi-buron-kasus-pinjol-ilegal-adalah-pemodal?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/22320088/sebesar-ini-ongkos-olimpiade-paris-2024?page=all',
#  'https://regional.kompas.com/read/2021/10/15/223000578/solo-terima-hibah-8-mobil-listrik-senilai-rp-1-4-m-gibran-sebut-untuk?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/222449966/danilla-tuan-tigabelas-dan-seringai-tuangkan-persona-dalam-be-the-meister?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/22223961/tagar-percumalaporpolisi-dinilai-sebagai-cermin-bagi-polisi-untuk-bebenah?page=all',
#  'https://www.kompas.com/badminton/read/2021/10/15/22181238/hasil-piala-thomas-lalui-drama-75-menit-jojo-bawa-indonesia-menang-3-0?page=all',
#  'https://www.kompas.com/food/read/2021/10/15/221700275/6-serabi-di-solo-ada-serabi-notosuman-ny.-lidia?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/22122008/untuk-kali-ketiga-berturut-turut-gp-shanghai-absen?page=all',
#  'https://regional.kompas.com/read/2021/10/15/220953778/peringati-hut-ke-76-jatim-khofifah-bagikan-ratusan-paket-sembako?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/220931866/di-penjara-jennifer-jill-ketakutan-sampai-tak-bisa-tidur-2-hari?page=all',
#  'https://regional.kompas.com/read/2021/10/15/220836078/gara-gara-barang-tak-dikembalikan-pria-ini-bacok-rekannya-hingga-luka-parah?page=all',
#  'https://regional.kompas.com/read/2021/10/15/220738978/11-siswa-mts-harapan-baru-ciamis-tewas-saat-susur-sungai-kegiatan-pramuka?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/220700376/5-cara-praktis-membersihkan-rumah-dalam-waktu-singkat-?page=all',
#  'https://regional.kompas.com/read/2021/10/15/220635578/kronologi-wanita-asal-ponorogo-tewas-di-pangkuan-putranya-diduga-dibunuh?page=all',
#  'https://www.kompas.com/badminton/read/2021/10/15/22042428/piala-thomas-marcus-kevin-ogah-pikirkan-juara?page=all',
#  'https://regional.kompas.com/read/2021/10/15/220208978/kasus-istri-siri-dibunuh-suami-di-surabaya-dipicu-cekcok-dugaan?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/220100623/mengapa-bintang-tampak-berwarna-putih-dan-berkelap-kelip-di-langit-?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/220000121/hotel-ikonik-milik-donald-trump-berganti-tuan?page=all',
#  'https://money.kompas.com/read/2021/10/15/220000726/bps--ada-geliat-ekonomi-karena-permintaan-dalam-negeri-meningkat?page=all',
#  'https://regional.kompas.com/read/2021/10/15/215724078/oknum-guru-sma-diduga-lecehkan-siswi-di-minahasa-selatan-ditahan-polisi?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/215606366/lesti-kejora-ungkap-cerita-awal-dekat-hingga-diajak-menikah-siri-duluan?page=all',
#  'https://www.kompas.com/global/read/2021/10/15/215543970/dapat-6000-tanda-tangan-petisi-orang-belum-divaksin-boleh-masuk-mal?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/21541341/polres-jakarta-barat-telusuri-legalitas-dan-aktivitas-7-perusahaan-pinjol?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/21501691/107-pinjol-terdaftar-resmi-di-ojk-begini-cara-ceknya?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/21471221/pemerintah-diminta-lindungi-pasar-muamalah-bagi-penerima-zakat-agar-tak?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/21414581/korban-kebakaran-di-krendang-mengungsi-di-dua-lokasi?page=all',
#  'https://bola.kompas.com/read/2021/10/15/21400038/kualifikasi-piala-asia-u23-tiba-di-tajikistan-indonesia-langsung-dapat-tantangan?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/213952666/sakit-hati-dituding-hamil-di-luar-nikah-lesti-kejora-sesama-perempuan-harus?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/213845576/deterjen-bubuk-vs-deterjen-cair-mana-yang-lebih-efektif?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/213700076/6-keuntungan-memiliki-meja-makan-kayu?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/213550266/squid-game-tadinya-akan-dibuat-jadi-film-panjang?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/213525623/who-booster-vaksin-covid-19-untuk-orang-dengan-gangguan-sistem-kekebalan?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/21303461/orangtua-belum-izinkan-anaknya-belajar-di-sekolah-5-smp-swasta-di-kota?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/213000121/transjakarta-sediakan-transportasi-untuk-kepulangan-kontingen-pon-dki-?page=all',
#  'https://bola.kompas.com/read/2021/10/15/21300068/piala-thomas-bermain-agresif-jadi-kunci-anthony-ginting-raih-kemenangan?page=all',
#  'https://travel.kompas.com/read/2021/10/15/212900027/4-tips-menginap-di-la-ranch-glamping-adventure-pekalongan-harus-reservasi?page=all',
#  'https://regional.kompas.com/read/2021/10/15/212824678/pemkot-madiun-gelar-vaksinasi-di-pasar-sasar-pedagang-dan-pengunjung-warga?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/21272121/sebaran-19318-kasus-aktif-covid-19-jawa-tengah-terbanyak?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/21210088/alasan-irfan-jaya-bisa-main-untuk-ps-sleman-meski-baru-dari-luar-negeri?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/211800923/jenis-anestesi-berdasarkan-fungsinya?page=all',
#  'https://regional.kompas.com/read/2021/10/15/211732278/hasil-asesmen-kemenkes-34-daerah-di-jatim-masuk-level-1-tersisa-4-daerah-di?page=all',
#  'https://regional.kompas.com/read/2021/10/15/211431178/capaian-vaksinasi-80-persen-ptm-terbatas-di-wonogiri-bakal-digelar-pekan?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/211235366/rilis-dvd-heliotropisme-fourtwnty-suguhkan-1-lagu-yang-belum-pernah-dirilis?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/21113011/fakta-penangkapan-direktur-tv-swasta-disebut-sebarkan-konten-provokatif?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/21111741/polri-karyawan-sindikat-pinjol-ilegal-digaji-rp-15-juta-rp-20-juta-tiap?page=all',
#  'https://www.kompas.com/food/read/2021/10/15/211100475/9-resep-serabi-sederhana-ada-yang-bisa-dicetak-pakai-teflon?page=all',
#  'https://lifestyle.kompas.com/read/2021/10/15/211006920/10-cara-mengatasi-perut-kembung-bisa-dicoba-di-rumah?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/210631366/langsung-hamil-usai-nikah-agama-lesti-kejora-perasaan-campur-aduk?page=all',
#  'https://money.kompas.com/read/2021/10/15/210500326/cara-daftar-vaksinasi-covid-19-di-prudential?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/210145776/desain-di-set-serial-squid-game-khas-anak-anak-tapi-menegangkan?page=all',
#  'https://money.kompas.com/read/2021/10/15/210000426/menhub--aturan-soal-bandara-perairan-di-indonesia-masih-sangat-minimalis?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/210000123/5-khasiat-buah-jambu-biji-yang-telah-terbukti-secara-ilmiah?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/21000078/aturan-servis-bola-voli-yang-mengenai-net?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/210000721/sempat-mangkrak-8-tahun-proyek-antasari-45-kembali-berlanjut-siapa?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/210000876/5-tanaman-hias-terpopuler-yang-tidak-disarankan-untuk-pemula-?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/205830966/film-yuni-terpilih-wakili-indonesia-dalam-seleksi-oscar-2022?page=all',
#  'https://regional.kompas.com/read/2021/10/15/205820178/aniaya-pacar-yang-masih-di-bawah-umur-residivis-kasus-pencabulan-ditangkap?page=all',
#  'https://regional.kompas.com/read/2021/10/15/205756178/sempat-terbengkalai-stasiun-indro-gresik-mulai-difungsikan-untuk-kereta-api?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20551661/korban-kebakaran-di-krendang-dapat-bantuan-makan-2-kali-sehari?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/20504518/perancis-cari-uang-untuk-pembiayaan-olimpiade-paris-2024?page=all',
#  'https://www.kompas.com/badminton/read/2021/10/15/20503838/hasil-piala-thomas-berjuang-dengan-jari-terluka-marcus-kevin-bawa?page=all',
#  'https://travel.kompas.com/read/2021/10/15/204839227/masuk-50-desa-wisata-terbaik-desa-wisata-selasari-pangandaran-andalkan-wisata?page=all',
#  'https://regional.kompas.com/read/2021/10/15/204646178/bharatu-supian-anggota-brimob-yang-gugur-di-papua-dimakamkan-di-kampung?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20460041/polisi-selidiki-penyebab-kebakaran-permukiman-di-tambora?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/204523523/hasil-hasil-kebudayaan-abris-sous-roche?page=all',
#  'https://regional.kompas.com/read/2021/10/15/204503778/wali-kota-ambon-idealnya-rs-lapangan-tidak-ditutup-tetapi-ini-memberatkan?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/20443231/sejak-2018-kominfo-tutup-4874-akun-pinjol-ilegal?page=all',
#  'https://bola.kompas.com/read/2021/10/15/20400018/bhayangkara-vs-persib-the-guardian-optimistis-kalahkan-maung-bandung?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20382941/update-15-oktober-tambah-3-kasus-di-kota-tangerang-55-pasien-covid-19?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/203629166/istri-lutfi-agizal-mengaku-tak-suka-suaminya-bikin-ulah-di-media-sosial?page=all',
#  'https://bola.kompas.com/read/2021/10/15/20353228/hasil-liga-1-pss-sleman-vs-barito-putera-irfan-jaya-cetak-2-gol-super-elja?page=all',
#  'https://www.kompas.com/tren/read/2021/10/15/203500665/-hoaks-bunga-kitolod-dapat-mengobati-katarak-mata-minus-plus-dan-tumor-mata?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/203426666/rindu-traveling-obati-dengan-tonton-6-drama-korea-ini?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/203200023/pengertian-dan-fungsi-pembuluh-arteri?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20315781/zaim-saidi-ingin-gandeng-mui-dan-baznas-untuk-lanjutkan-zakat-dinar?page=all',
#  'https://money.kompas.com/read/2021/10/15/203100126/menteri-esdm-minta-pertamina-jaga-produksi-migas-blok-rokan?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/203035866/sempat-takut-masuk-penjara-jennifer-jill-selnya-jorok?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/203000421/harga-tanah-selangit-jakarta-makin-tak-terjangkau-kelas-menengah-bawah?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20290351/dki-jakarta-peringkat-kedua-pon-xx-papua?page=all',
#  'https://money.kompas.com/read/2021/10/15/202500926/lion-air-sesuaikan-tarif-tes-rt-pcr-mulai-berlaku-besok-?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/202206866/akui-nikah-siri-duluan-rizky-billar-itu-suatu-hal-yang-membanggakan-bagi?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/202200876/mengapa-kucing-suka-menguyah-kabel-ini-alasan-dan-cara-mengatasinya?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/20200068/pertandingan-karate-berlangsung-aman-ketum-koni-puji-pb-forki?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20184561/kapolres-kota-tangerang-siap-mundur-dari-jabatannya-jika?page=all',
#  'https://regional.kompas.com/read/2021/10/15/201822678/antisipasi-banjir-bupati-sumedang-ingatkan-warga-siaga-saat-musim-hujan?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/20173201/timsel-minta-warga-yang-merasa-memenuhi-syarat-jadi-bakal-calon-anggota-kpu?page=all',
#  'https://www.kompas.com/food/read/2021/10/15/200900975/4-cara-panggang-serabi-dengan-cetakan-hasilnya-matang-merata?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/200631766/rumah-tangganya-didoakan-cepat-cerai-begini-tanggapan-lutfi-agizal?page=all',
#  'https://www.kompas.com/global/read/2021/10/15/200517870/putin-2000-anggota-isis-berkumpul-di-afghanistan-utara-akan-menyamar-jadi?page=all',
#  'https://www.kompas.com/tren/read/2021/10/15/200500465/apakah-google-bisa-mendeteksi-password-yang-bocor-?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20042781/zaim-saidi-divonis-tak-bersalah-pasar-muamalah-di-depok-akan-jalan-lagi?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/20031131/adik-eks-bupati-lampung-utara-diduga-terima-rp-23-miliar-untuk-kepentingan?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/200200323/kenapa-awan-berwarna-putih-tapi-terkadang-gelap-?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/20012801/pembahasan-apbd-p-2021-molor-anggota-dprd-yang-lambat-bukan-kami-tapi?page=all',
#  'https://money.kompas.com/read/2021/10/15/200100326/linkedin-bakal-tutup-layanannya-di-china?page=all',
#  'https://money.kompas.com/read/2021/10/15/200000126/6-tips-jitu-ala-yasa-singgih-dalam-membangun-brand-dari-nol?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/200000121/desember-2021-metland-buka-hotel-bintang-empat-dekat-bandara-kertajati?page=all',
#  'https://money.kompas.com/read/2021/10/15/200000326/cara-mengajukan-kredit-sepeda-motor-di-bca?page=all',
#  'https://health.kompas.com/penyakit/read/2021/10/15/200000968/takikardia?page=all',
#  'https://bola.kompas.com/read/2021/10/15/20000028/-bhayangkara-fc-vs-persib-maung-bandung-wajib-unjuk-ketajaman?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/19584761/ojk-imbau-masyarakat-meminjam-ke-pinjol-resmi-yang-terdaftar?page=all',
#  'https://lifestyle.kompas.com/read/2021/10/15/195735720/gara-gara-pakai-baju-longgar-bella-hadid-disangka-lupa-kenakan-celana?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/19553861/puskesmas-kemayoran-gelar-vaksinasi-covid-19-malam-hari?page=all',
#  'https://otomotif.kompas.com/read/2021/10/15/195100115/peralihan-penggunaan-kendaraan-listrik-sebaiknya-berlangsung-alami?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/195000366/lirik-lagu-faking-love-anitta-feat.-saweetie?page=all',
#  'https://lifestyle.kompas.com/read/2021/10/15/194542520/manfaat-dan-kebaikan-yang-ditawarkan-jahe?page=all',
#  'https://regional.kompas.com/read/2021/10/15/194534478/pelajar-smp-di-surabaya-sabet-3-medali-emas-loncat-indah-di-pon-xx-papua?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/194500276/3-tips-mendekorasi-ruangan-dengan-warna-hijau-sage-?page=all',
#  'https://money.kompas.com/read/2021/10/15/194412726/bantu-tkm-di-papua-kemenaker-serahkan-rp-40-juta-untuk-setiap-kelompok-usaha?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/194235866/bebas-dari-kasus-penyalahgunaan-narkoba-jennifer-jill-kini-selektif-pilih?page=all',
#  'https://money.kompas.com/read/2021/10/15/194130726/gaikindo-sebut-peralihan-ke-kendaraan-listrik-bisa-dilakukan-secara-alamiah?page=all',
#  'https://otomotif.kompas.com/read/2021/10/15/194100915/-video-menjajal-fitur-toyota-safety-sense-di-raize?page=all',
#  'https://bola.kompas.com/read/2021/10/15/19400048/potensi-ekonomi-dari-menggelar-superbike-bisa-capai-rp-500-miliar-?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/194000466/lirik-dan-chord-lagu-cannonball-blues-the-carter-family?page=all',
#  'https://www.kompas.com/badminton/read/2021/10/15/19384668/hasil-piala-thomas-anthony-ginting-berhasil-revans-indonesia-vs?page=all',
#  'https://regional.kompas.com/read/2021/10/15/193756378/antisipasi-kerumunan-saat-libur-maulid-nabi-pemkot-yogyakarta-turunkan-tim?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/19372451/polisi-banting-pedemo-mahasiswa-tuntut-kapolres-kota-tangerang-dicopot?page=all',
#  'https://biz.kompas.com/read/2021/10/15/193626528/galesia-beef-sudah-ada-di-indonesia-daging-berkualitas-hasil-silang-sapi?page=all',
#  'https://www.kompas.com/homey/read/2021/10/15/193606176/5-hal-dasar-memelihara-tanaman-untuk-pemula?page=all',
#  'https://regional.kompas.com/read/2021/10/15/193509878/anggaran-terbatas-pemkot-ambon-tutup-rs-lapangan-covid-19?page=all',
#  'https://lifestyle.kompas.com/read/2021/10/15/193320420/ketahui-bahaya-pakai-masker-berulang-kali?page=all',
#  'https://regional.kompas.com/read/2021/10/15/193315878/atlet-paralayang-jabar-torehkan-prestasi-terbaik-di-pon-papua-setelah?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/193219866/fourtwnty-rilis-dvd-tur-konser-bertajuk-heliotropisme?page=all',
#  'https://nasional.kompas.com/read/2021/10/15/19321411/saat-soeharto-tolak-gelar-doktor-honoris-causa-dari-ui?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/193200823/resisten-antimikroba-masalah-global-serius-ini-strategi-kurangi-risikonya?page=all',
#  'https://otomotif.kompas.com/read/2021/10/15/193100315/sumber-daya-melimpah-tidak-jamin-indonesia-berhasil-di-era-kendaraan?page=all',
#  'https://www.kompas.com/properti/read/2021/10/15/193000121/luar-biasa-134-proyek-strategis-nasional-selesai-dibangun-akhir-2021?page=all',
#  'https://www.kompas.com/tren/read/2021/10/15/193000965/kata-bmkg-soal-siklus-gempa-100-tahunan-di-selatan-jawa--tidak-benar-?page=all',
#  'https://www.kompas.com/sains/read/2021/10/15/193000923/skrining-dan-deteksi-dini-kanker-payudara-apa-bedanya-?page=all',
#  'https://money.kompas.com/read/2021/10/15/193000826/tiga-cara-ganti-kartu-atm-bca-dari-strip-magnetik-ke-chip?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/193000866/lirik-lagu-the-weekend-bibi-dan-88rising?page=all',
#  'https://tekno.kompas.com/read/2021/10/15/19290047/google-hapus-aplikasi-pinjol-ilegal-dari-play-store-jika-diminta-pemerintah?page=all',
#  'https://money.kompas.com/read/2021/10/15/192700526/usai-gojek-tokopedia-merger-transaksi-gofood-naik?page=all',
#  'https://www.kompas.com/edu/read/2021/10/15/192528071/hari-perempuan-pedesaan-internasional-dan-7-semangat-yang-perlu-diteladani?page=all',
#  'https://regional.kompas.com/read/2021/10/15/192239378/seorang-remaja-di-karawang-diduga-memproduksi-narkotika?page=all',
#  'https://otomotif.kompas.com/read/2021/10/15/192100015/biaya-perawatan-kia-sonet-100.000-km-tembus-rp-14-juta?page=all',
#  'https://www.kompas.com/sports/read/2021/10/15/19200028/klasemen-akhir-medali-pon-xx-papua-2021--jabar-juara-umum-dki-jakarta?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/19180381/saat-mahasiswa-yang-dibanting-polisi-datangi-berbagai-rs-korban-mengaku?page=all',
#  'https://travel.kompas.com/read/2021/10/15/191800227/maroko-cabut-bebas-visa-wni-harga-paket-wisata-jadi-lebih-mahal?page=all',
#  'https://megapolitan.kompas.com/read/2021/10/15/19164291/dprd-dan-pemprov-dki-jakarta-kembali-gelar-rapat-anggaran-di-hotel-grand?page=all',
#  'https://www.kompas.com/hype/read/2021/10/15/191637666/rhoma-irama-jika-saya-meninggal-dunia-soneta-selesai?page=all',
#  'https://www.kompas.com/tren/read/2021/10/15/191632865/waspada-tawaran-palsu-pinjol-ilegal-ini-daftar-terbaru-pinjol-terdaftar-dan?page=all',
#  'https://regional.kompas.com/read/2021/10/15/191537378/kronologi-pembunuhan-petani-di-riau-berawal-ajakan-pesta-sabu-hingga-mayat?page=all']
